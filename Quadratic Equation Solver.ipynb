# %%
import math
import cmath

def solve_quadratic(a: float, b: float, c: float) -> str:
   # A quadratic equation must have an 'a' value other than 0

   if a == 0:
     return "Error: If 'a' is 0, this is a linear equation, not quadratic."
     #calculate the d(discriminant)

     discriminant = b**2-4*a*c
    # branch logic based on the value of the d
     if d>0:
       # two distinct root
       root1 = (-b+math.sqrt(discriminant))/(2*a)
       root2 = (-b-math.sqrt(discriminant))/(2*a)
       return f"two distinct real root:\nx1 = {root1:.4f}\nx2={root2:.4f} "
     elif d==0:
       # one repeated real root
        root = -b/(2*a)
     return f"one repeated real root:\nx = {root:.4f}"
   else:
      # two complex root(imeginary ) root
       # we use cmath.sqrt besause  math.sqrt will crash on negetive number
      discriminant = b**2 -4*a*c
      root1 = (-b + cmath.sqrt(discriminant))/(2*a)
      root2 = (-b-cmath.sqrt(discriminant))/(2*a)
      return f"two complex root:\nx1 = {root1:.4f}\nx2 = {root2:.4f}"


def main():
   print ("===quadratic equation solver===")
   print("solves equations of the from: ax**2+bx +c = 0\n")
   try:
      a = float(input("enter coefficient a:"))
      b = float ( input("enter coefficient b:"))
      c = float(input("enter coefficient c:"))

      print("\n----solution----")
      result = solve_quadratic(a,b,c)
      print(result)

   except ValueError:
      print("\nError : please enter valid numerical valuse for the coeficients .")
if __name__ == "__main__":
   main()
# Out:
# ===quadratic equation solver===
# solves equations of the from: ax**2+bx +c = 0
#
# enter coefficient a:1
# enter coefficient b:-4
# enter coefficient c:4
#
# ----solution----
# two complex root:
# x1 = 2.0000+0.0000j
# x2 = 2.0000+0.0000j

# %%
411
